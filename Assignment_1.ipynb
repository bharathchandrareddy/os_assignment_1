# %%
import os

#printing the menu

print("hi What do you want to check today?")
print("Menu:")
print("1. List directory contents")
print("2. Print working directory ")
print("3. Create a new directory")
print("4. Display a message")
print("5. Concatenate and display content of a file")
print('6. Exit')
# Out:
# hi What do you want to check today?
# Menu:
# 1. List directory contents
# 2. Print working directory
# 3. Create a new directory
# 4. Display a message
# 5. Concatenate and display content of a file
# 6. Exit

# %%
d_path = 'C://Users//PC//Desktop//'
#path = "C://Users//PC//Desktop//"
#user_path = input("enter the default directory you want to choose to work with")
code = True
while code:
    
    try:
        x=int(input("enter a number from the menu 1-6 \n"))
        if x>6:
            print("Enter a number less than 6")

        elif x==1:
            try:

                directory= input("enter the directory name you want to work with \n ")
                path = os.path.join(d_path,directory)  #join the path of directory
                print(os.listdir(path))
            except:
                print("Enter a valid directory name from your computer to work with")
        elif x==2:
            print("your working directory path is '%s'" %os.getcwd())  #to print the current working directory
        elif x==3:
            try:

                directory= input("enter the directory name which you want to create \n")
                path = os.path.join(d_path,directory)
                os.mkdir(path)
                print("directory '%s' created" %directory)
            except:
                print("error in creating the directory")
        elif x==4:
            message = input('type the message you want to display')
            print(f"displayed message:{message}")  #to display the message
        elif x==5:   #opening the files, concatinating the message and to diplay the final contents of the code
            try:
                file = input('enter the file name you want to open\n')
                file_name = file+'.txt'
                file_content = input("Write what you want to add to the file\n")
                with open(file_name, 'a') as file:
                    file.write(file_content)
                    file.write('\n')
                    file.close()
                response = input('do you want to look at the contents of the file?(yes or no)')
                if response == 'yes':
                    
                    with open(file_name,'r') as file:
                        content = file.read()
                        print(content)
                        file.close()
                
                    
            except:
                print('error occured while creating the file')
            
        elif x==6:  #to break the loop
            code = False
            print("Exited")
    except:
        print("Enter a valid number")
# Out:
# enter a number from the menu 1-6
# 1
# enter the directory name you want to work with
#  Class lectures
# ['CS 540 operating systems', 'DL practice code']
# rerun the code to execute commands
# enter a number from the menu 1-6
# 2
# your working directory path is 'C:\Users\PC\Desktop\Class lectures\CS 540 operating systems'
# rerun the code to execute commands
# enter a number from the menu 1-6
# 3
# enter the directory name which you want to create
# sample
# directory 'sample' created
# rerun the code to execute commands
# enter a number from the menu 1-6
# 4
# type the message you want to displayhello
# displayed message:hello
# rerun the code to execute commands
# enter a number from the menu 1-6
# 5
# enter the file name you want to open
# sample
# Write what you want to add to the file
# sdbfkbadghjha
# do you want to look at the contents of the file?(yes or no)yes
# my name is bharathhow are you?jhaljdhfkjlsajdfl
# hgsdhf
# kjasdhfhajskdflkadhsfljhajhdfjlhadf
# nvnbbjabd;
# sdbfkbadghjha
#
# rerun the code to execute commands
# enter a number from the menu 1-6
# 6
# Exited
# rerun the code to execute commands
